# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
avg_dataframe = pd.read_csv('player_avg_df.csv')
test_matches = pd.read_csv('player_avg_test.csv')

# %%
avg_dataframe.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
matches = test_matches[['team', 'opp_team', 'result']]
#matches
# Out:
#                team        opp_team  result
# 0               DRX  SANDBOX Gaming       1
# 1                T1  SANDBOX Gaming       1
# 2             Gen.G  SANDBOX Gaming       1
# 3     Team Dynamics  SANDBOX Gaming      -1
# 4     Team Dynamics  SANDBOX Gaming      -1
# ...             ...             ...     ...
# 1554     Resurgence        Impunity      -1
# 1555          Gen.G      LGD Gaming       1
# 1556   Team SoloMid      LGD Gaming      -1
# 1557         Fnatic      LGD Gaming       1
# 1558  Machi Esports          Suning      -1
#
# [1559 rows x 3 columns]

# %%
averages_red = avg_dataframe.copy()

# %%
columns_blue = avg_dataframe.columns
#columns_blue
# Out:
# Index(['gamelength', 'result', 'kills', 'deaths', 'assists', 'doublekills',
#        'triplekills', 'quadrakills', 'pentakills', 'firstblood',
#        ...
#        'jng_xpdiffat15', 'mid_xpdiffat15', 'bot_xpdiffat15', 'sup_xpdiffat15',
#        'top_csdiffat15', 'jng_csdiffat15', 'mid_csdiffat15', 'bot_csdiffat15',
#        'sup_csdiffat15', 'team'],
#       dtype='object', length=278)

# %%
columns_red = []
for column in averages_red.columns:
    columns_red.append('opp_' + column)
    
averages_red.columns = columns_red
averages_red
# Out:
#      opp_gamelength  opp_result  opp_kills  opp_deaths  opp_assists  \
# 0       1954.412500    0.412500  10.300000   11.775000    24.450000
# 1       2024.704545    0.647727  12.772727    8.397727    30.625000
# 2       1968.787879    0.616162  12.404040   10.373737    29.000000
# 3       2042.214286    0.523810  12.297619   11.857143    29.285714
# 4       1995.647059    0.647059  16.803922   11.725490    40.078431
# ..              ...         ...        ...         ...          ...
# 201     1874.000000    0.428571  12.714286   17.714286    32.000000
# 202     2127.600000    0.200000  10.600000   10.200000    29.200000
# 203     1815.750000    0.500000  18.250000   15.750000    29.750000
# 204     2020.500000    0.714286  13.428571   10.785714    31.571429
# 205     2081.500000    0.666667  15.500000   13.000000    34.166667
#
#      opp_doublekills  opp_triplekills  opp_quadrakills  opp_pentakills  \
# 0           1.237500         0.175000         0.025000         0.01250
# ...

# %%
cl = avg_dataframe.columns.tolist() + averages_red.columns.tolist() + ['result']

# %%
full_matches = []
for i in range(len(matches)):
    blue_team = avg_dataframe[avg_dataframe['team'] == matches.iloc[i]['team']].values.tolist()
    red_team = avg_dataframe[avg_dataframe['team'] == matches.iloc[i]['opp_team']].values.tolist()
    
    temp = blue_team[0] + red_team[0] + [matches.iloc[i]['result']]
    full_matches.append(temp)

# %%
df = pd.DataFrame(full_matches, columns = cl)
df
# Out:
#        gamelength    result      kills     deaths    assists  doublekills  \
# 0     1968.787879  0.616162  12.404040  10.373737  29.000000     1.404040
# 1     2024.704545  0.647727  12.772727   8.397727  30.625000     1.659091
# 2     1944.539326  0.719101  13.629213   8.786517  31.247191     1.707865
# 3     1931.242857  0.614286  12.614286  10.271429  29.800000     1.385714
# 4     1931.242857  0.614286  12.614286  10.271429  29.800000     1.385714
# ...           ...       ...        ...        ...        ...          ...
# 1554  1888.757576  0.272727   9.484848  13.818182  22.696970     0.909091
# 1555  1944.539326  0.719101  13.629213   8.786517  31.247191     1.707865
# 1556  2133.901639  0.557377  12.131148  10.737705  28.885246     1.163934
# 1557  1910.254902  0.607843  14.254902  13.313725  31.901961     1.509804
# 1558  1924.925373  0.686567  13.895522  11.029851  32.179104     1.626866
#
#       triplekills  quadrakills  pentakills  firstblood  team kpm      ckpm  \
# ...

# %%
df.to_csv('players_train_df.csv')
